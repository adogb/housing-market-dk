# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import datetime

# %% [markdown]
# # Gathering data

# %%
url = 'https://www.boliga.dk/resultat?zipCodes=2720'
r = requests.get(url)
content=r.content
soup=BeautifulSoup(content)

# %%
now = datetime.datetime.now()
retrieved = now.strftime(("%Y-%m-%d %H:%M:%S"))

# %%
tag_list=soup.find("app-housing-list-results").div.div.next_sibling.find_all("app-housing-list-item")

# %%
data_list = []
for tag in tag_list:
    # checking skuffesag i.e. hidden listings - they won't be used
    if tag.find("app-listing-information-hidden"):
        #print("skuffesag")
        continue
        
    # dividing listing container in top, middle and bottom parts for readability
    top_info = tag.find("app-listing-information-lg").div.div
    middle_info = top_info.parent.contents[3].div.div
    bottom_info = middle_info.parent.contents[2].div
    
    # information scraping
    link = tag.a['href']
    address=top_info.div.div.span.string
    #print(address)
    city=address.parent.next_sibling.string
    #print(city)
    price=top_info.div.next_sibling.div.contents[1]
    #print(price)
    price_m2=price.parent.next_sibling.string
    #print(pricePerM2)
    housing_type = middle_info.contents[1].label.contents[1].string
    date_added = middle_info.contents[2].p.contents[0]
    rooms = bottom_info.contents[0].span.string
    area = bottom_info.contents[1].span.string
    energy = bottom_info.contents[2].span.string
    year_built = bottom_info.contents[3].span.string
    ground = bottom_info.contents[4].span.string
    monthly_cost = bottom_info.contents[5].span.string
    
    # appending data dictionnary to data_list. BeautifulSoup converts HTML non-breaking spaces (&nbsp) to \xa0 (unicode),
    # so we need to remove them.
    data_list.append({
        "link": link,
        "address": str(address).replace(u'\xa0', u' '),
        "city": city,
        "housing_type": housing_type,
        "price": str(price).replace(u'\xa0', u' '),
        "price_m2": str(price_m2).replace(u'\xa0', u' '),
        "area": area,
        "rooms": rooms,
        "ground": ground,
        "energy": energy,
        "year_built": year_built,
        "monthly_cost": monthly_cost,
        "date_added": date_added,
        "retrieved": retrieved
    })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-99359eb9c81b> in <module>
#       8     # diving listing container in top, middle and bottom parts for readability
#       9     top_info = tag.find("app-listing-information-lg").div.div
# ---> 10     middle_info = top_info.parent.contents[3].div.div
#      11     bottom_info = middle_info.parent.contents[2].div
#      12
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     919             return self
#     920         else:
# --> 921             raise AttributeError(
#     922                 "'%s' object has no attribute '%s'" % (
#     923                     self.__class__.__name__, attr))
#
# AttributeError: 'Comment' object has no attribute 'div'

# %%
data_list
# Out:
# [{'link': '/bolig/1805981/vinkelager_3_1_th_2720_vanloese',
#   'address': 'Vinkelager 3, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.275.000 kr. ',
#   'price_m2': ' 39.912 kr. / m² ',
#   'area': ' 57 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1957 ',
#   'monthly_cost': ' Ejerudgift: 2.483 kr. / md. ',
#   'date_added': ' Oprettet 16. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1805618/flakholmen_23__st_5_2720_vanloese',
#   'address': 'Flakholmen 23  st. 5., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.750.000 kr. ',
#   'price_m2': ' 40.441 kr. / m² ',
#   'area': ' 68 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.058 kr. / md. ',
#   'date_added': ' Oprettet 14. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1805552/frederiksgaards_alle_8b_1_th_2720_vanloese',
#   'address': 'Frederiksgårds Allé 8B, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.795.000 kr. ',
#   'price_m2': ' 35.379 kr. / m² ',
#   'area': ' 79 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 4.254 kr. / md. ',
#   'date_added': ' Oprettet 14. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1805127/aadalsvej_23b_st_th_2720_vanloese',
#   'address': 'Ådalsvej 23B, st. th, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.250.000 kr. ',
#   'price_m2': ' 40.178 kr. / m² ',
#   'area': ' 56 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.676 kr. / md. ',
#   'date_added': ' Oprettet 13. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1805293/jyllingevej_62__2_tv_2720_vanloese',
#   'address': 'Jyllingevej 62  2. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.195.000 kr. ',
#   'price_m2': ' 28.526 kr. / m² ',
#   'area': ' 112 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 4.359 kr. / md. ',
#   'date_added': ' Oprettet 13. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1804961/kirkebjerg_alle_43_1_tv_2720_vanloese',
#   'address': 'Kirkebjerg Allé 43, 1 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.045.000 kr. ',
#   'price_m2': ' 40.098 kr. / m² ',
#   'area': ' 51 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1936 ',
#   'monthly_cost': ' Ejerudgift: 1.783 kr. / md. ',
#   'date_added': ' Oprettet 12. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1804132/groennehoej_9_2_th_2720_vanloese',
#   'address': 'Grønnehøj 9, 2. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.195.000 kr. ',
#   'price_m2': ' 34.841 kr. / m² ',
#   'area': ' 63 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1936 ',
#   'monthly_cost': ' Ejerudgift: 3.163 kr. / md. ',
#   'date_added': ' Oprettet 9. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1804004/arnestedet_21_st_th_2720_vanloese',
#   'address': 'Arnestedet 21, ST. TH, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.750.000 kr. ',
#   'price_m2': ' 47.413 kr. / m² ',
#   'area': ' 58 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.608 kr. / md. ',
#   'date_added': ' Oprettet 9. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1804087/markskellet_11_2_tv_2720_vanloese',
#   'address': 'Markskellet 11, 2. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.095.000 kr. ',
#   'price_m2': ' 40.194 kr. / m² ',
#   'area': ' 77 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1936 ',
#   'monthly_cost': ' Ejerudgift: 3.628 kr. / md. ',
#   'date_added': ' Oprettet 9. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1803631/aalekistevej_110b_1_th_2720_vanloese',
#   'address': 'Ålekistevej 110B, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.450.000 kr. ',
#   'price_m2': ' 45.370 kr. / m² ',
#   'area': ' 54 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 2.240 kr. / md. ',
#   'date_added': ' Oprettet 8. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1803724/flakholmen_10_1_th_2720_vanloese',
#   'address': 'Flakholmen 10, 1 th, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.595.000 kr. ',
#   'price_m2': ' 40.546 kr. / m² ',
#   'area': ' 64 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 3.094 kr. / md. ',
#   'date_added': ' Oprettet 8. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1802953/vinkelager_27__1_th_2720_vanloese',
#   'address': 'Vinkelager 27  1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 4.595.000 kr. ',
#   'price_m2': ' 45.049 kr. / m² ',
#   'area': ' 102 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1970 ',
#   'monthly_cost': ' Ejerudgift: 2.698 kr. / md. ',
#   'date_added': ' Oprettet 7. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1803102/aadalsvej_63_2_th_2720_vanloese',
#   'address': 'Ådalsvej 63, 2. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.750.000 kr. ',
#   'price_m2': ' 44.871 kr. / m² ',
#   'area': ' 39 m² ',
#   'rooms': ' 1 værelse ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 1.602 kr. / md. ',
#   'date_added': ' Oprettet 7. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1803103/af_beyers_vej_8_st_th_2720_vanloese',
#   'address': 'A.F. Beyers Vej 8, st.. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.298.000 kr. ',
#   'price_m2': ' 39.620 kr. / m² ',
#   'area': ' 58 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1933 ',
#   'monthly_cost': ' Ejerudgift: 2.328 kr. / md. ',
#   'date_added': ' Oprettet 7. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1803104/helga_larsens_plads_10_4_th_2720_vanloese',
#   'address': 'Helga Larsens Plads 10, 4. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.098.000 kr. ',
#   'price_m2': ' 40.763 kr. / m² ',
#   'area': ' 76 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1958 ',
#   'monthly_cost': ' Ejerudgift: 3.636 kr. / md. ',
#   'date_added': ' Oprettet 7. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1803034/bogholder_alle_48a_3_tv_2720_vanloese',
#   'address': 'Bogholder Allé 48A, 3 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.475.000 kr. ',
#   'price_m2': ' 44.551 kr. / m² ',
#   'area': ' 78 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1966 ',
#   'monthly_cost': ' Ejerudgift: 3.196 kr. / md. ',
#   'date_added': ' Oprettet 7. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1802745/groendals_parkvej_16__1_th_2720_vanloese',
#   'address': 'Grøndals Parkvej 16  1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.895.000 kr. ',
#   'price_m2': ' 40.154 kr. / m² ',
#   'area': ' 97 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.663 kr. / md. ',
#   'date_added': ' Oprettet 5. jul. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1800792/aalekistevej_126_st_th_2720_vanloese',
#   'address': 'Ålekistevej 126, st th, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 40.223 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: B ',
#   'year_built': ' 2007 ',
#   'monthly_cost': ' Ejerudgift: 2.717 kr. / md. ',
#   'date_added': ' Oprettet 30. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1798604/sallingvej_76_1_th_2720_vanloese',
#   'address': 'Sallingvej 76, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.350.000 kr. ',
#   'price_m2': ' 36.718 kr. / m² ',
#   'area': ' 64 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.558 kr. / md. ',
#   'date_added': ' Oprettet 24. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1798615/jernbane_alle_55_3_doerlejl_14_2720_vanloese',
#   'address': 'Jernbane Allé 55, 3. Dør/lejl. 14, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.850.000 kr. ',
#   'price_m2': ' 39.041 kr. / m² ',
#   'area': ' 73 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1975 ',
#   'monthly_cost': ' Ejerudgift: 2.793 kr. / md. ',
#   'date_added': ' Oprettet 24. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1797931/jernbane_alle_55_1_5_2720_vanloese',
#   'address': 'Jernbane Allé 55, 1. 5., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 36.917 kr. / m² ',
#   'area': ' 73 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1975 ',
#   'monthly_cost': ' Ejerudgift: 3.754 kr. / md. ',
#   'date_added': ' Oprettet 23. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1796782/linde_alle_11_2_207_2720_vanloese',
#   'address': 'Linde Allé 11, 2. 207., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.475.000 kr. ',
#   'price_m2': ' 45.000 kr. / m² ',
#   'area': ' 55 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1971 ',
#   'monthly_cost': ' Ejerudgift: 2.548 kr. / md. ',
#   'date_added': ' Oprettet 19. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1797003/bellahoejvej_115_1_tv_2720_vanloese',
#   'address': 'Bellahøjvej 115, 1. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.995.000 kr. ',
#   'price_m2': ' 44.388 kr. / m² ',
#   'area': ' 90 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1907 ',
#   'monthly_cost': ' Ejerudgift: 4.071 kr. / md. ',
#   'date_added': ' Oprettet 19. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1796478/langdraget_11_1_th_2720_vanloese',
#   'address': 'Langdraget 11, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.648.000 kr. ',
#   'price_m2': ' 42.031 kr. / m² ',
#   'area': ' 63 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.463 kr. / md. ',
#   'date_added': ' Oprettet 18. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1795910/aaloekkevej_36_2_th_2720_vanloese',
#   'address': 'Åløkkevej 36, 2. TH, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.995.000 kr. ',
#   'price_m2': ' 39.117 kr. / m² ',
#   'area': ' 51 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 2.099 kr. / md. ',
#   'date_added': ' Oprettet 17. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1795967/sallingvej_76_3_tv_2720_vanloese',
#   'address': 'Sallingvej 76, 3 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.398.000 kr. ',
#   'price_m2': ' 38.677 kr. / m² ',
#   'area': ' 62 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.213 kr. / md. ',
#   'date_added': ' Oprettet 17. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1795113/flakholmen_9_2_tv_2720_vanloese',
#   'address': 'Flakholmen 9, 2. tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.495.000 kr. ',
#   'price_m2': ' 40.901 kr. / m² ',
#   'area': ' 61 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 2.884 kr. / md. ',
#   'date_added': ' Oprettet 15. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1795423/flakholmen_4_3_2720_vanloese',
#   'address': 'Flakholmen 4, 3., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.798.000 kr. ',
#   'price_m2': ' 33.026 kr. / m² ',
#   'area': ' 115 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 4.315 kr. / md. ',
#   'date_added': ' Oprettet 16. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1794741/soendervigvej_128_1_th_2720_vanloese',
#   'address': 'Søndervigvej 128, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.948.000 kr. ',
#   'price_m2': ' 36.074 kr. / m² ',
#   'area': ' 54 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1946 ',
#   'monthly_cost': ' Ejerudgift: 2.331 kr. / md. ',
#   'date_added': ' Oprettet 15. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1794042/frederiksgaards_alle_14_1_th_2720_vanloese',
#   'address': 'Frederiksgårds Allé 14, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.495.000 kr. ',
#   'price_m2': ' 40.901 kr. / m² ',
#   'area': ' 61 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 2.796 kr. / md. ',
#   'date_added': ' Oprettet 12. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1794043/skjulhoej_alle_81_1_tv_2720_vanloese',
#   'address': 'Skjulhøj Allé 81, 1. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 40.223 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1939 ',
#   'monthly_cost': ' Ejerudgift: 2.897 kr. / md. ',
#   'date_added': ' Oprettet 12. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1792510/jernbane_alle_8__st_tv_2720_vanloese',
#   'address': 'Jernbane Allé 8  st. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 4.775.000 kr. ',
#   'price_m2': ' 37.304 kr. / m² ',
#   'area': ' 128 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1933 ',
#   'monthly_cost': ' Ejerudgift: 4.348 kr. / md. ',
#   'date_added': ' Oprettet 9. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1790803/jydeholmen_13a_2_th_2720_vanloese',
#   'address': 'Jydeholmen 13A, 2. th, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.990.000 kr. ',
#   'price_m2': ' 43.260 kr. / m² ',
#   'area': ' 46 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1908 ',
#   'monthly_cost': ' Ejerudgift: 2.441 kr. / md. ',
#   'date_added': ' Oprettet 4. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1789808/dybendalsvej_67_1_mf_2720_vanloese',
#   'address': 'Dybendalsvej 67, 1. mf., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.995.000 kr. ',
#   'price_m2': ' 39.117 kr. / m² ',
#   'area': ' 51 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1957 ',
#   'monthly_cost': ' Ejerudgift: 3.056 kr. / md. ',
#   'date_added': ' Oprettet 2. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1789960/vinkelager_9_st_tv_2720_vanloese',
#   'address': 'Vinkelager 9, ST TV, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.095.000 kr. ',
#   'price_m2': ' 37.410 kr. / m² ',
#   'area': ' 56 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1957 ',
#   'monthly_cost': ' Ejerudgift: 2.495 kr. / md. ',
#   'date_added': ' Oprettet 3. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1789946/gudenaavej_18_4_tv_2720_vanloese',
#   'address': 'Gudenåvej 18, 4 TV, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.795.000 kr. ',
#   'price_m2': ' 41.716 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 2.657 kr. / md. ',
#   'date_added': ' Oprettet 3. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1789945/markskellet_2_2_tv_2720_vanloese',
#   'address': 'Markskellet 2, 2 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.195.000 kr. ',
#   'price_m2': ' 37.588 kr. / m² ',
#   'area': ' 85 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1932 ',
#   'monthly_cost': ' Ejerudgift: 4.208 kr. / md. ',
#   'date_added': ' Oprettet 3. jun. 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1787752/aadalsvej_23a_2_tv_2720_vanloese',
#   'address': 'Ådalsvej 23A, 2 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.795.000 kr. ',
#   'price_m2': ' 40.795 kr. / m² ',
#   'area': ' 44 m² ',
#   'rooms': ' 1 værelse ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.476 kr. / md. ',
#   'date_added': ' Oprettet 28. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1787516/himmerlandsvej_21_st_tv_2720_vanloese',
#   'address': 'Himmerlandsvej 21, st.. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.495.000 kr. ',
#   'price_m2': ' 41.583 kr. / m² ',
#   'area': ' 60 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 2.250 kr. / md. ',
#   'date_added': ' Oprettet 27. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1787531/sallingvej_76_2_tv_2720_vanloese',
#   'address': 'Sallingvej 76, 2. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.495.000 kr. ',
#   'price_m2': ' 37.238 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.831 kr. / md. ',
#   'date_added': ' Oprettet 27. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1787096/langdraget_17__3_2720_vanloese',
#   'address': 'Langdraget 17  3., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.095.000 kr. ',
#   'price_m2': ' 39.528 kr. / m² ',
#   'area': ' 53 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 2.025 kr. / md. ',
#   'date_added': ' Oprettet 26. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1786357/soendervigvej_134_1_tv_2720_vanloese',
#   'address': 'Søndervigvej 134, 1. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.948.000 kr. ',
#   'price_m2': ' 36.074 kr. / m² ',
#   'area': ' 54 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1946 ',
#   'monthly_cost': ' Ejerudgift: 2.463 kr. / md. ',
#   'date_added': ' Oprettet 22. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1786385/kirkebjerg_alle_47_st_tv_2720_vanloese',
#   'address': 'Kirkebjerg Allé 47, ST. TV, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.595.000 kr. ',
#   'price_m2': ' 36.041 kr. / m² ',
#   'area': ' 72 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1936 ',
#   'monthly_cost': ' Ejerudgift: 2.278 kr. / md. ',
#   'date_added': ' Oprettet 22. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1786344/skjulhoej_alle_22e_1_2720_vanloese',
#   'address': 'Skjulhøj Allé 22E, 1, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 4.395.000 kr. ',
#   'price_m2': ' 107.195 kr. / m² ',
#   'area': ' 41 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1899 ',
#   'monthly_cost': ' Ejerudgift: 2.854 kr. / md. ',
#   'date_added': ' Oprettet 22. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1785367/linde_alle_11_3_doerlejl_302_2720_vanloese',
#   'address': 'Linde Allé 11, 3. Dør/lejl. 302, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.195.000 kr. ',
#   'price_m2': ' 44.795 kr. / m² ',
#   'area': ' 49 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1971 ',
#   'monthly_cost': ' Ejerudgift: 2.338 kr. / md. ',
#   'date_added': ' Oprettet 21. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1784783/skjulhoej_alle_11_1_th_2720_vanloese',
#   'address': 'Skjulhøj Allé 11, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.250.000 kr. ',
#   'price_m2': ' 38.135 kr. / m² ',
#   'area': ' 59 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1939 ',
#   'monthly_cost': ' Ejerudgift: 3.184 kr. / md. ',
#   'date_added': ' Oprettet 19. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1784934/flakholmen_8_3_2720_vanloese',
#   'address': 'Flakholmen 8, 3., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.795.000 kr. ',
#   'price_m2': ' 34.189 kr. / m² ',
#   'area': ' 111 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 4.315 kr. / md. ',
#   'date_added': ' Oprettet 20. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1784677/loevholmen_15_1_10_2720_vanloese',
#   'address': 'Løvholmen 15, 1 10, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.495.000 kr. ',
#   'price_m2': ' 41.607 kr. / m² ',
#   'area': ' 84 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1963 ',
#   'monthly_cost': ' Ejerudgift: 3.138 kr. / md. ',
#   'date_added': ' Oprettet 19. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'},
#  {'link': '/bolig/1782817/flakholmen_34_2_tv_2720_vanloese',
#   'address': 'Flakholmen 34, 2 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.795.000 kr. ',
#   'price_m2': ' 43.671 kr. / m² ',
#   'area': ' 64 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1940 ',
#   'monthly_cost': ' Ejerudgift: 2.373 kr. / md. ',
#   'date_added': ' Oprettet 13. maj 2021 ',
#   'retrieved': '2021-07-16 15:35:41'}]

# %%
df = pd.DataFrame(data_list)
df
# Out:
#                                                  link  \
# 0      /bolig/1805981/vinkelager_3_1_th_2720_vanloese
# 1    /bolig/1805618/flakholmen_23__st_5_2720_vanloese
# 2   /bolig/1805552/frederiksgaards_alle_8b_1_th_27...
# 3    /bolig/1805127/aadalsvej_23b_st_th_2720_vanloese
# 4   /bolig/1805293/jyllingevej_62__2_tv_2720_vanloese
# 5   /bolig/1804961/kirkebjerg_alle_43_1_tv_2720_va...
# 6     /bolig/1804132/groennehoej_9_2_th_2720_vanloese
# 7    /bolig/1804004/arnestedet_21_st_th_2720_vanloese
# 8    /bolig/1804087/markskellet_11_2_tv_2720_vanloese
# 9   /bolig/1803631/aalekistevej_110b_1_th_2720_van...
# 10    /bolig/1803724/flakholmen_10_1_th_2720_vanloese
# 11   /bolig/1802953/vinkelager_27__1_th_2720_vanloese
# 12     /bolig/1803102/aadalsvej_63_2_th_2720_vanloese
# 13  /bolig/1803103/af_beyers_vej_8_st_th_2720_vanl...
# 14  /bolig/1803104/helga_larsens_plads_10_4_th_272...
# 15  /bolig/1803034/bogholder_alle_48a_3_tv_2720_va...
# 16  /bolig/1802745/groendals_parkvej_16__1_th_2720...
# 17  /bolig/1800792/aalekistevej_126_st_th_2720_van...
# 18    /bolig/1798604/sallingvej_76_1_th_2720_vanloese
# 19  /bolig/1798615/jernbane_alle_55_3_doerlejl_14_...
# 20  /bolig/1797931/jernbane_alle_55_1_5_2720_vanloese
# 21   /bolig/1796782/linde_alle_11_2_207_2720_vanloese
# 22  /bolig/1797003/bellahoejvej_115_1_tv_2720_vanl...
# 23    /bolig/1796478/langdraget_11_1_th_2720_vanloese
# 24   /bolig/1795910/aaloekkevej_36_2_th_2720_vanloese
# 25    /bolig/1795967/sallingvej_76_3_tv_2720_vanloese
# 26     /bolig/1795113/flakholmen_9_2_tv_2720_vanloese
# 27        /bolig/1795423/flakholmen_4_3_2720_vanloese
# 28  /bolig/1794741/soendervigvej_128_1_th_2720_van...
# 29  /bolig/1794042/frederiksgaards_alle_14_1_th_27...
# 30  /bolig/1794043/skjulhoej_alle_81_1_tv_2720_van...
# 31  /bolig/1792510/jernbane_alle_8__st_tv_2720_van...
# 32   /bolig/1790803/jydeholmen_13a_2_th_2720_vanloese
# 33  /bolig/1789808/dybendalsvej_67_1_mf_2720_vanloese
# 34    /bolig/1789960/vinkelager_9_st_tv_2720_vanloese
# 35    /bolig/1789946/gudenaavej_18_4_tv_2720_vanloese
# 36    /bolig/1789945/markskellet_2_2_tv_2720_vanloese
# 37    /bolig/1787752/aadalsvej_23a_2_tv_2720_vanloese
# 38  /bolig/1787516/himmerlandsvej_21_st_tv_2720_va...
# 39    /bolig/1787531/sallingvej_76_2_tv_2720_vanloese
# 40      /bolig/1787096/langdraget_17__3_2720_vanloese
# 41  /bolig/1786357/soendervigvej_134_1_tv_2720_van...
# 42  /bolig/1786385/kirkebjerg_alle_47_st_tv_2720_v...
# 43  /bolig/1786344/skjulhoej_alle_22e_1_2720_vanloese
# 44  /bolig/1785367/linde_alle_11_3_doerlejl_302_27...
# 45  /bolig/1784783/skjulhoej_alle_11_1_th_2720_van...
# 46        /bolig/1784934/flakholmen_8_3_2720_vanloese
# 47    /bolig/1784677/loevholmen_15_1_10_2720_vanloese
# 48    /bolig/1782817/flakholmen_34_2_tv_2720_vanloese
#
#                                 address          city   housing_type  \
# 0                Vinkelager 3, 1. th.,   2720 Vanløse  Ejerlejlighed
# 1               Flakholmen 23  st. 5.,   2720 Vanløse  Ejerlejlighed
# 2      Frederiksgårds Allé 8B, 1. th.,   2720 Vanløse  Ejerlejlighed
# 3                Ådalsvej 23B, st. th,   2720 Vanløse  Ejerlejlighed
# 4              Jyllingevej 62  2. tv.,   2720 Vanløse  Ejerlejlighed
# 5            Kirkebjerg Allé 43, 1 tv,   2720 Vanløse  Ejerlejlighed
# 6                 Grønnehøj 9, 2. th.,   2720 Vanløse  Ejerlejlighed
# 7               Arnestedet 21, ST. TH,   2720 Vanløse  Ejerlejlighed
# 8              Markskellet 11, 2. tv.,   2720 Vanløse  Ejerlejlighed
# 9            Ålekistevej 110B, 1. th.,   2720 Vanløse  Ejerlejlighed
# 10                Flakholmen 10, 1 th,   2720 Vanløse  Ejerlejlighed
# 11              Vinkelager 27  1. th.,   2720 Vanløse  Ejerlejlighed
# 12                Ådalsvej 63, 2. th.,   2720 Vanløse  Ejerlejlighed
# 13        A.F. Beyers Vej 8, st.. th.,   2720 Vanløse  Ejerlejlighed
# 14     Helga Larsens Plads 10, 4. th.,   2720 Vanløse  Ejerlejlighed
# 15           Bogholder Allé 48A, 3 tv,   2720 Vanløse  Ejerlejlighed
# 16        Grøndals Parkvej 16  1. th.,   2720 Vanløse  Ejerlejlighed
# 17             Ålekistevej 126, st th,   2720 Vanløse  Ejerlejlighed
# 18              Sallingvej 76, 1. th.,   2720 Vanløse  Ejerlejlighed
# 19  Jernbane Allé 55, 3. Dør/lejl. 14,   2720 Vanløse  Ejerlejlighed
# 20            Jernbane Allé 55, 1. 5.,   2720 Vanløse  Ejerlejlighed
# 21             Linde Allé 11, 2. 207.,   2720 Vanløse  Ejerlejlighed
# 22            Bellahøjvej 115, 1. tv.,   2720 Vanløse  Ejerlejlighed
# 23              Langdraget 11, 1. th.,   2720 Vanløse  Ejerlejlighed
# 24                Åløkkevej 36, 2. TH,   2720 Vanløse  Ejerlejlighed
# 25                Sallingvej 76, 3 tv,   2720 Vanløse  Ejerlejlighed
# 26                Flakholmen 9, 2. tv,   2720 Vanløse  Ejerlejlighed
# 27                   Flakholmen 4, 3.,   2720 Vanløse  Ejerlejlighed
# 28           Søndervigvej 128, 1. th.,   2720 Vanløse  Ejerlejlighed
# 29     Frederiksgårds Allé 14, 1. th.,   2720 Vanløse  Ejerlejlighed
# 30           Skjulhøj Allé 81, 1. tv.,   2720 Vanløse  Ejerlejlighed
# 31           Jernbane Allé 8  st. tv.,   2720 Vanløse  Ejerlejlighed
# 32              Jydeholmen 13A, 2. th,   2720 Vanløse  Ejerlejlighed
# 33            Dybendalsvej 67, 1. mf.,   2720 Vanløse  Ejerlejlighed
# 34                Vinkelager 9, ST TV,   2720 Vanløse  Ejerlejlighed
# 35                 Gudenåvej 18, 4 TV,   2720 Vanløse  Ejerlejlighed
# 36                Markskellet 2, 2 tv,   2720 Vanløse  Ejerlejlighed
# 37                 Ådalsvej 23A, 2 tv,   2720 Vanløse  Ejerlejlighed
# 38        Himmerlandsvej 21, st.. tv.,   2720 Vanløse  Ejerlejlighed
# 39              Sallingvej 76, 2. tv.,   2720 Vanløse  Ejerlejlighed
# 40                  Langdraget 17  3.,   2720 Vanløse  Ejerlejlighed
# 41           Søndervigvej 134, 1. tv.,   2720 Vanløse  Ejerlejlighed
# 42         Kirkebjerg Allé 47, ST. TV,   2720 Vanløse  Ejerlejlighed
# 43               Skjulhøj Allé 22E, 1,   2720 Vanløse  Ejerlejlighed
# 44    Linde Allé 11, 3. Dør/lejl. 302,   2720 Vanløse  Ejerlejlighed
# 45           Skjulhøj Allé 11, 1. th.,   2720 Vanløse  Ejerlejlighed
# 46                   Flakholmen 8, 3.,   2720 Vanløse  Ejerlejlighed
# 47                 Løvholmen 15, 1 10,   2720 Vanløse  Ejerlejlighed
# 48                Flakholmen 34, 2 tv,   2720 Vanløse  Ejerlejlighed
#
#               price            price_m2      area          rooms  ground  \
# 0    2.275.000 kr.     39.912 kr. / m²     57 m²    Værelser: 2    0 m²
# 1    2.750.000 kr.     40.441 kr. / m²     68 m²    Værelser: 3    0 m²
# 2    2.795.000 kr.     35.379 kr. / m²     79 m²    Værelser: 3    0 m²
# 3    2.250.000 kr.     40.178 kr. / m²     56 m²    Værelser: 2    0 m²
# 4    3.195.000 kr.     28.526 kr. / m²    112 m²    Værelser: 3    0 m²
# 5    2.045.000 kr.     40.098 kr. / m²     51 m²    Værelser: 2    0 m²
# 6    2.195.000 kr.     34.841 kr. / m²     63 m²    Værelser: 2    0 m²
# 7    2.750.000 kr.     47.413 kr. / m²     58 m²    Værelser: 2    0 m²
# 8    3.095.000 kr.     40.194 kr. / m²     77 m²    Værelser: 2    0 m²
# 9    2.450.000 kr.     45.370 kr. / m²     54 m²    Værelser: 2    0 m²
# 10   2.595.000 kr.     40.546 kr. / m²     64 m²    Værelser: 3    0 m²
# 11   4.595.000 kr.     45.049 kr. / m²    102 m²    Værelser: 4    0 m²
# 12   1.750.000 kr.     44.871 kr. / m²     39 m²      1 værelse    0 m²
# 13   2.298.000 kr.     39.620 kr. / m²     58 m²    Værelser: 2    0 m²
# 14   3.098.000 kr.     40.763 kr. / m²     76 m²    Værelser: 3    0 m²
# 15   3.475.000 kr.     44.551 kr. / m²     78 m²    Værelser: 2    0 m²
# 16   3.895.000 kr.     40.154 kr. / m²     97 m²    Værelser: 4    0 m²
# 17   2.695.000 kr.     40.223 kr. / m²     67 m²    Værelser: 2    0 m²
# 18   2.350.000 kr.     36.718 kr. / m²     64 m²    Værelser: 2    0 m²
# 19   2.850.000 kr.     39.041 kr. / m²     73 m²    Værelser: 2    0 m²
# 20   2.695.000 kr.     36.917 kr. / m²     73 m²    Værelser: 2    0 m²
# 21   2.475.000 kr.     45.000 kr. / m²     55 m²    Værelser: 2    0 m²
# 22   3.995.000 kr.     44.388 kr. / m²     90 m²    Værelser: 3    0 m²
# 23   2.648.000 kr.     42.031 kr. / m²     63 m²    Værelser: 3    0 m²
# 24   1.995.000 kr.     39.117 kr. / m²     51 m²    Værelser: 2    0 m²
# 25   2.398.000 kr.     38.677 kr. / m²     62 m²    Værelser: 2    0 m²
# 26   2.495.000 kr.     40.901 kr. / m²     61 m²    Værelser: 3    0 m²
# 27   3.798.000 kr.     33.026 kr. / m²    115 m²    Værelser: 4    0 m²
# 28   1.948.000 kr.     36.074 kr. / m²     54 m²    Værelser: 2    0 m²
# 29   2.495.000 kr.     40.901 kr. / m²     61 m²    Værelser: 2    0 m²
# 30   2.695.000 kr.     40.223 kr. / m²     67 m²    Værelser: 3    0 m²
# 31   4.775.000 kr.     37.304 kr. / m²    128 m²    Værelser: 4    0 m²
# 32   1.990.000 kr.     43.260 kr. / m²     46 m²    Værelser: 2    0 m²
# 33   1.995.000 kr.     39.117 kr. / m²     51 m²    Værelser: 2    0 m²
# 34   2.095.000 kr.     37.410 kr. / m²     56 m²    Værelser: 2    0 m²
# 35   2.795.000 kr.     41.716 kr. / m²     67 m²    Værelser: 2    0 m²
# 36   3.195.000 kr.     37.588 kr. / m²     85 m²    Værelser: 3    0 m²
# 37   1.795.000 kr.     40.795 kr. / m²     44 m²      1 værelse    0 m²
# 38   2.495.000 kr.     41.583 kr. / m²     60 m²    Værelser: 2    0 m²
# 39   2.495.000 kr.     37.238 kr. / m²     67 m²    Værelser: 3    0 m²
# 40   2.095.000 kr.     39.528 kr. / m²     53 m²    Værelser: 2    0 m²
# 41   1.948.000 kr.     36.074 kr. / m²     54 m²    Værelser: 2    0 m²
# 42   2.595.000 kr.     36.041 kr. / m²     72 m²    Værelser: 3    0 m²
# 43   4.395.000 kr.    107.195 kr. / m²     41 m²    Værelser: 3    0 m²
# 44   2.195.000 kr.     44.795 kr. / m²     49 m²    Værelser: 2    0 m²
# 45   2.250.000 kr.     38.135 kr. / m²     59 m²    Værelser: 2    0 m²
# 46   3.795.000 kr.     34.189 kr. / m²    111 m²    Værelser: 4    0 m²
# 47   3.495.000 kr.     41.607 kr. / m²     84 m²    Værelser: 2    0 m²
# 48   2.795.000 kr.     43.671 kr. / m²     64 m²    Værelser: 3    0 m²
#
#               energy year_built                   monthly_cost  \
# 0    Energimærke: D       1957    Ejerudgift: 2.483 kr. / md.
# 1    Energimærke: E       1937    Ejerudgift: 3.058 kr. / md.
# 2    Energimærke: D       1934    Ejerudgift: 4.254 kr. / md.
# 3    Energimærke: D       1935    Ejerudgift: 2.676 kr. / md.
# 4    Energimærke: D       1934    Ejerudgift: 4.359 kr. / md.
# 5    Energimærke: D       1936    Ejerudgift: 1.783 kr. / md.
# 6    Energimærke: D       1936    Ejerudgift: 3.163 kr. / md.
# 7    Energimærke: D       1935    Ejerudgift: 2.608 kr. / md.
# 8    Energimærke: C       1936    Ejerudgift: 3.628 kr. / md.
# 9    Energimærke: D       1937    Ejerudgift: 2.240 kr. / md.
# 10   Energimærke: D       1938    Ejerudgift: 3.094 kr. / md.
# 11   Energimærke: C       1970    Ejerudgift: 2.698 kr. / md.
# 12   Energimærke: D       1937    Ejerudgift: 1.602 kr. / md.
# 13   Energimærke: E       1933    Ejerudgift: 2.328 kr. / md.
# 14   Energimærke: D       1958    Ejerudgift: 3.636 kr. / md.
# 15   Energimærke: D       1966    Ejerudgift: 3.196 kr. / md.
# 16   Energimærke: D       1937    Ejerudgift: 3.663 kr. / md.
# 17   Energimærke: B       2007    Ejerudgift: 2.717 kr. / md.
# 18   Energimærke: D       1937    Ejerudgift: 3.558 kr. / md.
# 19   Energimærke: C       1975    Ejerudgift: 2.793 kr. / md.
# 20   Energimærke: C       1975    Ejerudgift: 3.754 kr. / md.
# 21   Energimærke: E       1971    Ejerudgift: 2.548 kr. / md.
# 22   Energimærke: D       1907    Ejerudgift: 4.071 kr. / md.
# 23   Energimærke: E       1935    Ejerudgift: 2.463 kr. / md.
# 24   Energimærke: C       1937    Ejerudgift: 2.099 kr. / md.
# 25   Energimærke: D       1937    Ejerudgift: 3.213 kr. / md.
# 26   Energimærke: D       1938    Ejerudgift: 2.884 kr. / md.
# 27   Energimærke: D       1938    Ejerudgift: 4.315 kr. / md.
# 28   Energimærke: E       1946    Ejerudgift: 2.331 kr. / md.
# 29   Energimærke: D       1934    Ejerudgift: 2.796 kr. / md.
# 30   Energimærke: D       1939    Ejerudgift: 2.897 kr. / md.
# 31   Energimærke: D       1933    Ejerudgift: 4.348 kr. / md.
# 32   Energimærke: D       1908    Ejerudgift: 2.441 kr. / md.
# 33   Energimærke: D       1957    Ejerudgift: 3.056 kr. / md.
# 34   Energimærke: D       1957    Ejerudgift: 2.495 kr. / md.
# 35   Energimærke: C       1938    Ejerudgift: 2.657 kr. / md.
# 36   Energimærke: D       1932    Ejerudgift: 4.208 kr. / md.
# 37   Energimærke: D       1935    Ejerudgift: 2.476 kr. / md.
# 38   Energimærke: D       1934    Ejerudgift: 2.250 kr. / md.
# 39   Energimærke: D       1937    Ejerudgift: 3.831 kr. / md.
# 40   Energimærke: E       1934    Ejerudgift: 2.025 kr. / md.
# 41   Energimærke: E       1946    Ejerudgift: 2.463 kr. / md.
# 42   Energimærke: D       1936    Ejerudgift: 2.278 kr. / md.
# 43   Energimærke: D       1899    Ejerudgift: 2.854 kr. / md.
# 44   Energimærke: E       1971    Ejerudgift: 2.338 kr. / md.
# 45   Energimærke: D       1939    Ejerudgift: 3.184 kr. / md.
# 46   Energimærke: D       1938    Ejerudgift: 4.315 kr. / md.
# 47   Energimærke: C       1963    Ejerudgift: 3.138 kr. / md.
# 48   Energimærke: D       1940    Ejerudgift: 2.373 kr. / md.
#
#                   date_added            retrieved
# 0    Oprettet 16. jul. 2021   2021-07-16 15:35:41
# 1    Oprettet 14. jul. 2021   2021-07-16 15:35:41
# 2    Oprettet 14. jul. 2021   2021-07-16 15:35:41
# 3    Oprettet 13. jul. 2021   2021-07-16 15:35:41
# 4    Oprettet 13. jul. 2021   2021-07-16 15:35:41
# 5    Oprettet 12. jul. 2021   2021-07-16 15:35:41
# 6     Oprettet 9. jul. 2021   2021-07-16 15:35:41
# 7     Oprettet 9. jul. 2021   2021-07-16 15:35:41
# 8     Oprettet 9. jul. 2021   2021-07-16 15:35:41
# 9     Oprettet 8. jul. 2021   2021-07-16 15:35:41
# 10    Oprettet 8. jul. 2021   2021-07-16 15:35:41
# 11    Oprettet 7. jul. 2021   2021-07-16 15:35:41
# 12    Oprettet 7. jul. 2021   2021-07-16 15:35:41
# 13    Oprettet 7. jul. 2021   2021-07-16 15:35:41
# 14    Oprettet 7. jul. 2021   2021-07-16 15:35:41
# 15    Oprettet 7. jul. 2021   2021-07-16 15:35:41
# 16    Oprettet 5. jul. 2021   2021-07-16 15:35:41
# 17   Oprettet 30. jun. 2021   2021-07-16 15:35:41
# 18   Oprettet 24. jun. 2021   2021-07-16 15:35:41
# 19   Oprettet 24. jun. 2021   2021-07-16 15:35:41
# 20   Oprettet 23. jun. 2021   2021-07-16 15:35:41
# 21   Oprettet 19. jun. 2021   2021-07-16 15:35:41
# 22   Oprettet 19. jun. 2021   2021-07-16 15:35:41
# 23   Oprettet 18. jun. 2021   2021-07-16 15:35:41
# 24   Oprettet 17. jun. 2021   2021-07-16 15:35:41
# 25   Oprettet 17. jun. 2021   2021-07-16 15:35:41
# 26   Oprettet 15. jun. 2021   2021-07-16 15:35:41
# 27   Oprettet 16. jun. 2021   2021-07-16 15:35:41
# 28   Oprettet 15. jun. 2021   2021-07-16 15:35:41
# 29   Oprettet 12. jun. 2021   2021-07-16 15:35:41
# 30   Oprettet 12. jun. 2021   2021-07-16 15:35:41
# 31    Oprettet 9. jun. 2021   2021-07-16 15:35:41
# 32    Oprettet 4. jun. 2021   2021-07-16 15:35:41
# 33    Oprettet 2. jun. 2021   2021-07-16 15:35:41
# 34    Oprettet 3. jun. 2021   2021-07-16 15:35:41
# 35    Oprettet 3. jun. 2021   2021-07-16 15:35:41
# 36    Oprettet 3. jun. 2021   2021-07-16 15:35:41
# 37    Oprettet 28. maj 2021   2021-07-16 15:35:41
# 38    Oprettet 27. maj 2021   2021-07-16 15:35:41
# 39    Oprettet 27. maj 2021   2021-07-16 15:35:41
# 40    Oprettet 26. maj 2021   2021-07-16 15:35:41
# 41    Oprettet 22. maj 2021   2021-07-16 15:35:41
# 42    Oprettet 22. maj 2021   2021-07-16 15:35:41
# 43    Oprettet 22. maj 2021   2021-07-16 15:35:41
# 44    Oprettet 21. maj 2021   2021-07-16 15:35:41
# 45    Oprettet 19. maj 2021   2021-07-16 15:35:41
# 46    Oprettet 20. maj 2021   2021-07-16 15:35:41
# 47    Oprettet 19. maj 2021   2021-07-16 15:35:41
# 48    Oprettet 13. maj 2021   2021-07-16 15:35:41

# %% [markdown]
# # Cleaning data
#
# - add new column with ID extracted from link
# - remove comma at the end of address values
# - extract only relevant numbers from combined values
# - remove spaces at start and end of strings
# - transform date into format that can be converted to DateTime datatype
# - put floor and side to lowercase in address
# - fix data types

# %%
df_clean = df.copy()

# %%
df_clean["id"] = df_clean.link.str.split("/")[2]

# %%
# remove comma and space at the end of address values
df_clean.address = df_clean.address.str.rstrip(", ")

# %%
# extract numbers from strings for relevant columns
df_clean.price = df_clean.price.str.strip().str.rstrip(" kr.").str.replace(".","")
# Out:
# <ipython-input-17-cbf5a643e2b0>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean.price = df_clean.price.str.strip().str.rstrip(" kr.").str.replace(".","")

# %%
df_clean.price_m2 = df_clean.price_m2.str.strip().str.rstrip(" kr. / m²").str.replace(".","")
# Out:
# <ipython-input-18-c980f41c8fb6>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean.price_m2 = df_clean.price_m2.str.strip().str.rstrip(" kr. / m²").str.replace(".","")

# %%
df_clean.area = df_clean.area.str.strip().str.rstrip(" m²")

# %%
df_clean.monthly_cost = df_clean.monthly_cost.str.strip().str.rstrip(" kr. / md.").str.lstrip("Ejerudgift: ")\
                                                                                    .str.replace(".","")
# Out:
# <ipython-input-20-3f5de58f18cd>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean.monthly_cost = df_clean.monthly_cost.str.strip().str.rstrip(" kr. / md.").str.lstrip("Ejerudgift: ")\

# %%
df_clean.head()
# Out:
#                                                 link  \
# 0     /bolig/1805981/vinkelager_3_1_th_2720_vanloese
# 1   /bolig/1805618/flakholmen_23__st_5_2720_vanloese
# 2  /bolig/1805552/frederiksgaards_alle_8b_1_th_27...
# 3   /bolig/1805127/aadalsvej_23b_st_th_2720_vanloese
# 4  /bolig/1805293/jyllingevej_62__2_tv_2720_vanloese
#
#                           address          city   housing_type    price  \
# 0            Vinkelager 3, 1. th.  2720 Vanløse  Ejerlejlighed  2275000
# 1           Flakholmen 23  st. 5.  2720 Vanløse  Ejerlejlighed  2750000
# 2  Frederiksgårds Allé 8B, 1. th.  2720 Vanløse  Ejerlejlighed  2795000
# 3            Ådalsvej 23B, st. th  2720 Vanløse  Ejerlejlighed  2250000
# 4          Jyllingevej 62  2. tv.  2720 Vanløse  Ejerlejlighed  3195000
#
#   price_m2 area          rooms  ground            energy year_built  \
# 0    39912   57   Værelser: 2    0 m²    Energimærke: D       1957
# 1    40441   68   Værelser: 3    0 m²    Energimærke: E       1937
# 2    35379   79   Værelser: 3    0 m²    Energimærke: D       1934
# 3    40178   56   Værelser: 2    0 m²    Energimærke: D       1935
# 4    28526  112   Værelser: 3    0 m²    Energimærke: D       1934
#
#   monthly_cost                date_added            retrieved
# 0         2483   Oprettet 16. jul. 2021   2021-07-16 15:35:41
# 1         3058   Oprettet 14. jul. 2021   2021-07-16 15:35:41
# 2         4254   Oprettet 14. jul. 2021   2021-07-16 15:35:41
# 3         2676   Oprettet 13. jul. 2021   2021-07-16 15:35:41
# 4         4359   Oprettet 13. jul. 2021   2021-07-16 15:35:41

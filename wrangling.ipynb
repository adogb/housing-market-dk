# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # Gathering data

# %%
url = 'https://www.boliga.dk/resultat?propertyType=3&zipCodes=2720'
r = requests.get(url)
content=r.content
soup=BeautifulSoup(content)

# %%
tag_list=soup.find("app-housing-list-results").find("div").find("div").next_sibling.find_all("app-housing-list-item")

# %%
data_list = []
for tag in tag_list:
    # checking skuffesag i.e. hidden listings - they won't be used
    if tag.find("app-listing-information-hidden"):
        #print("skuffesag")
        continue
        
    # diving listing container in top, middle and bottom parts for readability
    top_info = tag.find("app-listing-information-lg").div.div
    middle_info = top_info.parent.contents[3].div.div
    bottom_info = middle_info.parent.contents[2].div
    
    # information scraping
    address=top_info.div.div.span.string
    #print(address)
    city=address.parent.next_sibling.string
    #print(city)
    price=top_info.div.next_sibling.div.contents[1]
    #print(price)
    price_m2=price.parent.next_sibling.string
    #print(pricePerM2)
    housing_type = middle_info.contents[1].label.contents[1].string
    date = middle_info.contents[2].p.contents[0]
    rooms = bottom_info.contents[0].span.string
    area = bottom_info.contents[1].span.string
    energy = bottom_info.contents[2].span.string
    year_built = bottom_info.contents[3].span.string
    ground = bottom_info.contents[4].span.string
    monthly_cost = bottom_info.contents[5].span.string
    
    # appending data dictionnary to data_list. BeautifulSoup converts HTML non-breaking spaces (&nbsp) to \xa0 (unicode),
    # so we need to remove them.
    data_list.append({
        "address": str(address).replace(u'\xa0', u' '),
        "city": city,
        "housing_type": housing_type,
        "price": str(price).replace(u'\xa0', u' '),
        "price_m2": str(price_m2).replace(u'\xa0', u' '),
        "area": area,
        "rooms": rooms,
        "ground": ground,
        "energy": energy,
        "year_built": year_built,
        "monthly_cost": monthly_cost,
        "date": date
    })

# %%
data_list
# Out:
# [{'address': 'Grønnehøj 9, 2. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.195.000 kr. ',
#   'price_m2': ' 34.841 kr. / m² ',
#   'area': ' 63 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1936 ',
#   'monthly_cost': ' Ejerudgift: 3.163 kr. / md. ',
#   'date': ' Oprettet 9. jul. 2021 '},
#  {'address': 'Arnestedet 21, ST. TH, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.750.000 kr. ',
#   'price_m2': ' 47.413 kr. / m² ',
#   'area': ' 58 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.608 kr. / md. ',
#   'date': ' Oprettet 9. jul. 2021 '},
#  {'address': 'Markskellet 11, 2. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.095.000 kr. ',
#   'price_m2': ' 40.194 kr. / m² ',
#   'area': ' 77 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1936 ',
#   'monthly_cost': ' Ejerudgift: 3.628 kr. / md. ',
#   'date': ' Oprettet 9. jul. 2021 '},
#  {'address': 'Ålekistevej 110B, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.450.000 kr. ',
#   'price_m2': ' 45.370 kr. / m² ',
#   'area': ' 54 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 2.240 kr. / md. ',
#   'date': ' Oprettet 8. jul. 2021 '},
#  {'address': 'Flakholmen 10, 1 th, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.595.000 kr. ',
#   'price_m2': ' 40.546 kr. / m² ',
#   'area': ' 64 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 3.094 kr. / md. ',
#   'date': ' Oprettet 8. jul. 2021 '},
#  {'address': 'Ådalsvej 63, 2. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.750.000 kr. ',
#   'price_m2': ' 44.871 kr. / m² ',
#   'area': ' 39 m² ',
#   'rooms': ' 1 værelse ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 1.602 kr. / md. ',
#   'date': ' Oprettet 7. jul. 2021 '},
#  {'address': 'A.F. Beyers Vej 8, st.. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.298.000 kr. ',
#   'price_m2': ' 39.620 kr. / m² ',
#   'area': ' 58 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1933 ',
#   'monthly_cost': ' Ejerudgift: 2.328 kr. / md. ',
#   'date': ' Oprettet 7. jul. 2021 '},
#  {'address': 'Helga Larsens Plads 10, 4. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.098.000 kr. ',
#   'price_m2': ' 40.763 kr. / m² ',
#   'area': ' 76 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1958 ',
#   'monthly_cost': ' Ejerudgift: 3.636 kr. / md. ',
#   'date': ' Oprettet 7. jul. 2021 '},
#  {'address': 'Bogholder Allé 48A, 3 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.475.000 kr. ',
#   'price_m2': ' 44.551 kr. / m² ',
#   'area': ' 78 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1966 ',
#   'monthly_cost': ' Ejerudgift: 3.196 kr. / md. ',
#   'date': ' Oprettet 7. jul. 2021 '},
#  {'address': 'Vinkelager 27  1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 4.595.000 kr. ',
#   'price_m2': ' 45.049 kr. / m² ',
#   'area': ' 102 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1970 ',
#   'monthly_cost': ' Ejerudgift: 2.698 kr. / md. ',
#   'date': ' Oprettet 7. jul. 2021 '},
#  {'address': 'Grøndals Parkvej 16  1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.895.000 kr. ',
#   'price_m2': ' 40.154 kr. / m² ',
#   'area': ' 97 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.663 kr. / md. ',
#   'date': ' Oprettet 5. jul. 2021 '},
#  {'address': 'Veras Allé 17B, 2. mf., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 48.125 kr. / m² ',
#   'area': ' 56 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 2.462 kr. / md. ',
#   'date': ' Oprettet 30. jun. 2021 '},
#  {'address': 'Ålekistevej 126, st th, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 40.223 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: B ',
#   'year_built': ' 2007 ',
#   'monthly_cost': ' Ejerudgift: 2.717 kr. / md. ',
#   'date': ' Oprettet 30. jun. 2021 '},
#  {'address': 'Bogholder Allé 46A  3. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.195.000 kr. ',
#   'price_m2': ' 40.961 kr. / m² ',
#   'area': ' 78 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1966 ',
#   'monthly_cost': ' Ejerudgift: 3.027 kr. / md. ',
#   'date': ' Oprettet 30. jun. 2021 '},
#  {'address': 'Jyllingevej 7  3. 9., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.145.000 kr. ',
#   'price_m2': ' 36.355 kr. / m² ',
#   'area': ' 59 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1974 ',
#   'monthly_cost': ' Ejerudgift: 1.744 kr. / md. ',
#   'date': ' Oprettet 24. jun. 2021 '},
#  {'address': 'Sallingvej 76, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.350.000 kr. ',
#   'price_m2': ' 36.718 kr. / m² ',
#   'area': ' 64 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.558 kr. / md. ',
#   'date': ' Oprettet 24. jun. 2021 '},
#  {'address': 'Jernbane Allé 55, 3. Dør/lejl. 14, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.850.000 kr. ',
#   'price_m2': ' 39.041 kr. / m² ',
#   'area': ' 73 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1975 ',
#   'monthly_cost': ' Ejerudgift: 2.793 kr. / md. ',
#   'date': ' Oprettet 24. jun. 2021 '},
#  {'address': 'Jernbane Allé 55, 1. 5., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 36.917 kr. / m² ',
#   'area': ' 73 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1975 ',
#   'monthly_cost': ' Ejerudgift: 3.754 kr. / md. ',
#   'date': ' Oprettet 23. jun. 2021 '},
#  {'address': 'Linde Allé 11, 2. 207., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.475.000 kr. ',
#   'price_m2': ' 45.000 kr. / m² ',
#   'area': ' 55 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1971 ',
#   'monthly_cost': ' Ejerudgift: 2.548 kr. / md. ',
#   'date': ' Oprettet 19. jun. 2021 '},
#  {'address': 'Bellahøjvej 115, 1. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.995.000 kr. ',
#   'price_m2': ' 44.388 kr. / m² ',
#   'area': ' 90 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1907 ',
#   'monthly_cost': ' Ejerudgift: 4.071 kr. / md. ',
#   'date': ' Oprettet 19. jun. 2021 '},
#  {'address': 'Langdraget 11, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.648.000 kr. ',
#   'price_m2': ' 42.031 kr. / m² ',
#   'area': ' 63 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.463 kr. / md. ',
#   'date': ' Oprettet 18. jun. 2021 '},
#  {'address': 'Åløkkevej 36, 2. TH, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.995.000 kr. ',
#   'price_m2': ' 39.117 kr. / m² ',
#   'area': ' 51 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 2.099 kr. / md. ',
#   'date': ' Oprettet 17. jun. 2021 '},
#  {'address': 'Sallingvej 76, 3 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.398.000 kr. ',
#   'price_m2': ' 38.677 kr. / m² ',
#   'area': ' 62 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.213 kr. / md. ',
#   'date': ' Oprettet 17. jun. 2021 '},
#  {'address': 'Flakholmen 9, 2. tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 44.180 kr. / m² ',
#   'area': ' 61 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 2.884 kr. / md. ',
#   'date': ' Oprettet 15. jun. 2021 '},
#  {'address': 'Flakholmen 4, 3., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.798.000 kr. ',
#   'price_m2': ' 33.026 kr. / m² ',
#   'area': ' 115 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 4.315 kr. / md. ',
#   'date': ' Oprettet 16. jun. 2021 '},
#  {'address': 'Søndervigvej 128, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.998.000 kr. ',
#   'price_m2': ' 37.000 kr. / m² ',
#   'area': ' 54 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1946 ',
#   'monthly_cost': ' Ejerudgift: 2.331 kr. / md. ',
#   'date': ' Oprettet 15. jun. 2021 '},
#  {'address': 'Frederiksgårds Allé 14, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.595.000 kr. ',
#   'price_m2': ' 42.540 kr. / m² ',
#   'area': ' 61 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 2.796 kr. / md. ',
#   'date': ' Oprettet 12. jun. 2021 '},
#  {'address': 'Skjulhøj Allé 81, 1. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.695.000 kr. ',
#   'price_m2': ' 40.223 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1939 ',
#   'monthly_cost': ' Ejerudgift: 2.897 kr. / md. ',
#   'date': ' Oprettet 12. jun. 2021 '},
#  {'address': 'Jernbane Allé 8  st. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 4.775.000 kr. ',
#   'price_m2': ' 37.304 kr. / m² ',
#   'area': ' 128 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1933 ',
#   'monthly_cost': ' Ejerudgift: 4.348 kr. / md. ',
#   'date': ' Oprettet 9. jun. 2021 '},
#  {'address': 'Jydeholmen 13A, 2. th, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.990.000 kr. ',
#   'price_m2': ' 43.260 kr. / m² ',
#   'area': ' 46 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1908 ',
#   'monthly_cost': ' Ejerudgift: 2.441 kr. / md. ',
#   'date': ' Oprettet 4. jun. 2021 '},
#  {'address': 'Bogholder Allé 46B, 2. TV, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.850.000 kr. ',
#   'price_m2': ' 36.538 kr. / m² ',
#   'area': ' 78 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1966 ',
#   'monthly_cost': ' Ejerudgift: 3.017 kr. / md. ',
#   'date': ' Oprettet 4. jun. 2021 '},
#  {'address': 'Dybendalsvej 67, 1. mf., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.995.000 kr. ',
#   'price_m2': ' 39.117 kr. / m² ',
#   'area': ' 51 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1957 ',
#   'monthly_cost': ' Ejerudgift: 3.056 kr. / md. ',
#   'date': ' Oprettet 2. jun. 2021 '},
#  {'address': 'Vinkelager 9, ST TV, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.095.000 kr. ',
#   'price_m2': ' 37.410 kr. / m² ',
#   'area': ' 56 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1957 ',
#   'monthly_cost': ' Ejerudgift: 2.495 kr. / md. ',
#   'date': ' Oprettet 3. jun. 2021 '},
#  {'address': 'Gudenåvej 18, 4 TV, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.795.000 kr. ',
#   'price_m2': ' 41.716 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 2.657 kr. / md. ',
#   'date': ' Oprettet 3. jun. 2021 '},
#  {'address': 'Markskellet 2, 2 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.195.000 kr. ',
#   'price_m2': ' 37.588 kr. / m² ',
#   'area': ' 85 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1932 ',
#   'monthly_cost': ' Ejerudgift: 4.208 kr. / md. ',
#   'date': ' Oprettet 3. jun. 2021 '},
#  {'address': 'Ådalsvej 23A, 2 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.795.000 kr. ',
#   'price_m2': ' 40.795 kr. / m² ',
#   'area': ' 44 m² ',
#   'rooms': ' 1 værelse ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.476 kr. / md. ',
#   'date': ' Oprettet 28. maj 2021 '},
#  {'address': 'Himmerlandsvej 21, st.. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.495.000 kr. ',
#   'price_m2': ' 41.583 kr. / m² ',
#   'area': ' 60 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 2.250 kr. / md. ',
#   'date': ' Oprettet 27. maj 2021 '},
#  {'address': 'Sallingvej 76, 2. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.595.000 kr. ',
#   'price_m2': ' 38.731 kr. / m² ',
#   'area': ' 67 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 3.831 kr. / md. ',
#   'date': ' Oprettet 27. maj 2021 '},
#  {'address': 'Langdraget 17  3., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.095.000 kr. ',
#   'price_m2': ' 39.528 kr. / m² ',
#   'area': ' 53 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1934 ',
#   'monthly_cost': ' Ejerudgift: 2.025 kr. / md. ',
#   'date': ' Oprettet 26. maj 2021 '},
#  {'address': 'Søndervigvej 134, 1. tv., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.948.000 kr. ',
#   'price_m2': ' 36.074 kr. / m² ',
#   'area': ' 54 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1946 ',
#   'monthly_cost': ' Ejerudgift: 2.463 kr. / md. ',
#   'date': ' Oprettet 22. maj 2021 '},
#  {'address': 'Kirkebjerg Allé 47, ST. TV, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.595.000 kr. ',
#   'price_m2': ' 36.041 kr. / m² ',
#   'area': ' 72 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1936 ',
#   'monthly_cost': ' Ejerudgift: 2.278 kr. / md. ',
#   'date': ' Oprettet 22. maj 2021 '},
#  {'address': 'Skjulhøj Allé 22E, 1, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 4.395.000 kr. ',
#   'price_m2': ' 107.195 kr. / m² ',
#   'area': ' 41 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1899 ',
#   'monthly_cost': ' Ejerudgift: 2.854 kr. / md. ',
#   'date': ' Oprettet 22. maj 2021 '},
#  {'address': 'Linde Allé 11, 3. Dør/lejl. 302, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.195.000 kr. ',
#   'price_m2': ' 44.795 kr. / m² ',
#   'area': ' 49 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: E ',
#   'year_built': ' 1971 ',
#   'monthly_cost': ' Ejerudgift: 2.338 kr. / md. ',
#   'date': ' Oprettet 21. maj 2021 '},
#  {'address': 'Skjulhøj Allé 11, 1. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.350.000 kr. ',
#   'price_m2': ' 39.830 kr. / m² ',
#   'area': ' 59 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1939 ',
#   'monthly_cost': ' Ejerudgift: 3.184 kr. / md. ',
#   'date': ' Oprettet 19. maj 2021 '},
#  {'address': 'Flakholmen 8, 3., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.795.000 kr. ',
#   'price_m2': ' 34.189 kr. / m² ',
#   'area': ' 111 m² ',
#   'rooms': ' Værelser: 4 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1938 ',
#   'monthly_cost': ' Ejerudgift: 4.315 kr. / md. ',
#   'date': ' Oprettet 20. maj 2021 '},
#  {'address': 'Løvholmen 15, 1 10, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 3.495.000 kr. ',
#   'price_m2': ' 41.607 kr. / m² ',
#   'area': ' 84 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1963 ',
#   'monthly_cost': ' Ejerudgift: 3.138 kr. / md. ',
#   'date': ' Oprettet 19. maj 2021 '},
#  {'address': 'Flakholmen 34, 2 tv, ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.795.000 kr. ',
#   'price_m2': ' 43.671 kr. / m² ',
#   'area': ' 64 m² ',
#   'rooms': ' Værelser: 3 ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1940 ',
#   'monthly_cost': ' Ejerudgift: 2.373 kr. / md. ',
#   'date': ' Oprettet 13. maj 2021 '},
#  {'address': 'Sallingvej 61, st.. 3., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 1.698.000 kr. ',
#   'price_m2': ' 34.653 kr. / m² ',
#   'area': ' 49 m² ',
#   'rooms': ' 1 værelse ',
#   'ground': ' 0 m² ',
#   'energy': ' Energimærke: C ',
#   'year_built': ' 1937 ',
#   'monthly_cost': ' Ejerudgift: 2.627 kr. / md. ',
#   'date': ' Oprettet 12. maj 2021 '},
#  {'address': 'Arnestedet 21, st. th., ',
#   'city': '2720 Vanløse',
#   'housing_type': 'Ejerlejlighed',
#   'price': ' 2.745.000 kr. ',
#   'price_m2': ' 47.327 kr. / m² ',
#   'area': ' 58 m² ',
#   'rooms': ' Værelser: 2 ',
#   'ground': ' 200 m² ',
#   'energy': ' Energimærke: D ',
#   'year_built': ' 1935 ',
#   'monthly_cost': ' Ejerudgift: 2.986 kr. / md. ',
#   'date': ' Oprettet 11. maj 2021 '}]

# %%
df = pd.DataFrame(data_list)
df
# Out:
#                                 address          city   housing_type  \
# 0                 Grønnehøj 9, 2. th.,   2720 Vanløse  Ejerlejlighed
# 1               Arnestedet 21, ST. TH,   2720 Vanløse  Ejerlejlighed
# 2              Markskellet 11, 2. tv.,   2720 Vanløse  Ejerlejlighed
# 3            Ålekistevej 110B, 1. th.,   2720 Vanløse  Ejerlejlighed
# 4                 Flakholmen 10, 1 th,   2720 Vanløse  Ejerlejlighed
# 5                 Ådalsvej 63, 2. th.,   2720 Vanløse  Ejerlejlighed
# 6         A.F. Beyers Vej 8, st.. th.,   2720 Vanløse  Ejerlejlighed
# 7      Helga Larsens Plads 10, 4. th.,   2720 Vanløse  Ejerlejlighed
# 8            Bogholder Allé 48A, 3 tv,   2720 Vanløse  Ejerlejlighed
# 9               Vinkelager 27  1. th.,   2720 Vanløse  Ejerlejlighed
# 10        Grøndals Parkvej 16  1. th.,   2720 Vanløse  Ejerlejlighed
# 11             Veras Allé 17B, 2. mf.,   2720 Vanløse  Ejerlejlighed
# 12             Ålekistevej 126, st th,   2720 Vanløse  Ejerlejlighed
# 13         Bogholder Allé 46A  3. th.,   2720 Vanløse  Ejerlejlighed
# 14               Jyllingevej 7  3. 9.,   2720 Vanløse  Ejerlejlighed
# 15              Sallingvej 76, 1. th.,   2720 Vanløse  Ejerlejlighed
# 16  Jernbane Allé 55, 3. Dør/lejl. 14,   2720 Vanløse  Ejerlejlighed
# 17            Jernbane Allé 55, 1. 5.,   2720 Vanløse  Ejerlejlighed
# 18             Linde Allé 11, 2. 207.,   2720 Vanløse  Ejerlejlighed
# 19            Bellahøjvej 115, 1. tv.,   2720 Vanløse  Ejerlejlighed
# 20              Langdraget 11, 1. th.,   2720 Vanløse  Ejerlejlighed
# 21                Åløkkevej 36, 2. TH,   2720 Vanløse  Ejerlejlighed
# 22                Sallingvej 76, 3 tv,   2720 Vanløse  Ejerlejlighed
# 23                Flakholmen 9, 2. tv,   2720 Vanløse  Ejerlejlighed
# 24                   Flakholmen 4, 3.,   2720 Vanløse  Ejerlejlighed
# 25           Søndervigvej 128, 1. th.,   2720 Vanløse  Ejerlejlighed
# 26     Frederiksgårds Allé 14, 1. th.,   2720 Vanløse  Ejerlejlighed
# 27           Skjulhøj Allé 81, 1. tv.,   2720 Vanløse  Ejerlejlighed
# 28           Jernbane Allé 8  st. tv.,   2720 Vanløse  Ejerlejlighed
# 29              Jydeholmen 13A, 2. th,   2720 Vanløse  Ejerlejlighed
# 30          Bogholder Allé 46B, 2. TV,   2720 Vanløse  Ejerlejlighed
# 31            Dybendalsvej 67, 1. mf.,   2720 Vanløse  Ejerlejlighed
# 32                Vinkelager 9, ST TV,   2720 Vanløse  Ejerlejlighed
# 33                 Gudenåvej 18, 4 TV,   2720 Vanløse  Ejerlejlighed
# 34                Markskellet 2, 2 tv,   2720 Vanløse  Ejerlejlighed
# 35                 Ådalsvej 23A, 2 tv,   2720 Vanløse  Ejerlejlighed
# 36        Himmerlandsvej 21, st.. tv.,   2720 Vanløse  Ejerlejlighed
# 37              Sallingvej 76, 2. tv.,   2720 Vanløse  Ejerlejlighed
# 38                  Langdraget 17  3.,   2720 Vanløse  Ejerlejlighed
# 39           Søndervigvej 134, 1. tv.,   2720 Vanløse  Ejerlejlighed
# 40         Kirkebjerg Allé 47, ST. TV,   2720 Vanløse  Ejerlejlighed
# 41               Skjulhøj Allé 22E, 1,   2720 Vanløse  Ejerlejlighed
# 42    Linde Allé 11, 3. Dør/lejl. 302,   2720 Vanløse  Ejerlejlighed
# 43           Skjulhøj Allé 11, 1. th.,   2720 Vanløse  Ejerlejlighed
# 44                   Flakholmen 8, 3.,   2720 Vanløse  Ejerlejlighed
# 45                 Løvholmen 15, 1 10,   2720 Vanløse  Ejerlejlighed
# 46                Flakholmen 34, 2 tv,   2720 Vanløse  Ejerlejlighed
# 47             Sallingvej 61, st.. 3.,   2720 Vanløse  Ejerlejlighed
# 48             Arnestedet 21, st. th.,   2720 Vanløse  Ejerlejlighed
#
#               price            price_m2      area          rooms    ground  \
# 0    2.195.000 kr.     34.841 kr. / m²     63 m²    Værelser: 2      0 m²
# 1    2.750.000 kr.     47.413 kr. / m²     58 m²    Værelser: 2      0 m²
# 2    3.095.000 kr.     40.194 kr. / m²     77 m²    Værelser: 2      0 m²
# 3    2.450.000 kr.     45.370 kr. / m²     54 m²    Værelser: 2      0 m²
# 4    2.595.000 kr.     40.546 kr. / m²     64 m²    Værelser: 3      0 m²
# 5    1.750.000 kr.     44.871 kr. / m²     39 m²      1 værelse      0 m²
# 6    2.298.000 kr.     39.620 kr. / m²     58 m²    Værelser: 2      0 m²
# 7    3.098.000 kr.     40.763 kr. / m²     76 m²    Værelser: 3      0 m²
# 8    3.475.000 kr.     44.551 kr. / m²     78 m²    Værelser: 2      0 m²
# 9    4.595.000 kr.     45.049 kr. / m²    102 m²    Værelser: 4      0 m²
# 10   3.895.000 kr.     40.154 kr. / m²     97 m²    Værelser: 4      0 m²
# 11   2.695.000 kr.     48.125 kr. / m²     56 m²    Værelser: 3      0 m²
# 12   2.695.000 kr.     40.223 kr. / m²     67 m²    Værelser: 2      0 m²
# 13   3.195.000 kr.     40.961 kr. / m²     78 m²    Værelser: 3      0 m²
# 14   2.145.000 kr.     36.355 kr. / m²     59 m²    Værelser: 2      0 m²
# 15   2.350.000 kr.     36.718 kr. / m²     64 m²    Værelser: 2      0 m²
# 16   2.850.000 kr.     39.041 kr. / m²     73 m²    Værelser: 2      0 m²
# 17   2.695.000 kr.     36.917 kr. / m²     73 m²    Værelser: 2      0 m²
# 18   2.475.000 kr.     45.000 kr. / m²     55 m²    Værelser: 2      0 m²
# 19   3.995.000 kr.     44.388 kr. / m²     90 m²    Værelser: 3      0 m²
# 20   2.648.000 kr.     42.031 kr. / m²     63 m²    Værelser: 3      0 m²
# 21   1.995.000 kr.     39.117 kr. / m²     51 m²    Værelser: 2      0 m²
# 22   2.398.000 kr.     38.677 kr. / m²     62 m²    Værelser: 2      0 m²
# 23   2.695.000 kr.     44.180 kr. / m²     61 m²    Værelser: 3      0 m²
# 24   3.798.000 kr.     33.026 kr. / m²    115 m²    Værelser: 4      0 m²
# 25   1.998.000 kr.     37.000 kr. / m²     54 m²    Værelser: 2      0 m²
# 26   2.595.000 kr.     42.540 kr. / m²     61 m²    Værelser: 2      0 m²
# 27   2.695.000 kr.     40.223 kr. / m²     67 m²    Værelser: 3      0 m²
# 28   4.775.000 kr.     37.304 kr. / m²    128 m²    Værelser: 4      0 m²
# 29   1.990.000 kr.     43.260 kr. / m²     46 m²    Værelser: 2      0 m²
# 30   2.850.000 kr.     36.538 kr. / m²     78 m²    Værelser: 2      0 m²
# 31   1.995.000 kr.     39.117 kr. / m²     51 m²    Værelser: 2      0 m²
# 32   2.095.000 kr.     37.410 kr. / m²     56 m²    Værelser: 2      0 m²
# 33   2.795.000 kr.     41.716 kr. / m²     67 m²    Værelser: 2      0 m²
# 34   3.195.000 kr.     37.588 kr. / m²     85 m²    Værelser: 3      0 m²
# 35   1.795.000 kr.     40.795 kr. / m²     44 m²      1 værelse      0 m²
# 36   2.495.000 kr.     41.583 kr. / m²     60 m²    Værelser: 2      0 m²
# 37   2.595.000 kr.     38.731 kr. / m²     67 m²    Værelser: 3      0 m²
# 38   2.095.000 kr.     39.528 kr. / m²     53 m²    Værelser: 2      0 m²
# 39   1.948.000 kr.     36.074 kr. / m²     54 m²    Værelser: 2      0 m²
# 40   2.595.000 kr.     36.041 kr. / m²     72 m²    Værelser: 3      0 m²
# 41   4.395.000 kr.    107.195 kr. / m²     41 m²    Værelser: 3      0 m²
# 42   2.195.000 kr.     44.795 kr. / m²     49 m²    Værelser: 2      0 m²
# 43   2.350.000 kr.     39.830 kr. / m²     59 m²    Værelser: 2      0 m²
# 44   3.795.000 kr.     34.189 kr. / m²    111 m²    Værelser: 4      0 m²
# 45   3.495.000 kr.     41.607 kr. / m²     84 m²    Værelser: 2      0 m²
# 46   2.795.000 kr.     43.671 kr. / m²     64 m²    Værelser: 3      0 m²
# 47   1.698.000 kr.     34.653 kr. / m²     49 m²      1 værelse      0 m²
# 48   2.745.000 kr.     47.327 kr. / m²     58 m²    Værelser: 2    200 m²
#
#               energy year_built                   monthly_cost  \
# 0    Energimærke: D       1936    Ejerudgift: 3.163 kr. / md.
# 1    Energimærke: D       1935    Ejerudgift: 2.608 kr. / md.
# 2    Energimærke: C       1936    Ejerudgift: 3.628 kr. / md.
# 3    Energimærke: D       1937    Ejerudgift: 2.240 kr. / md.
# 4    Energimærke: D       1938    Ejerudgift: 3.094 kr. / md.
# 5    Energimærke: D       1937    Ejerudgift: 1.602 kr. / md.
# 6    Energimærke: E       1933    Ejerudgift: 2.328 kr. / md.
# 7    Energimærke: D       1958    Ejerudgift: 3.636 kr. / md.
# 8    Energimærke: D       1966    Ejerudgift: 3.196 kr. / md.
# 9    Energimærke: C       1970    Ejerudgift: 2.698 kr. / md.
# 10   Energimærke: D       1937    Ejerudgift: 3.663 kr. / md.
# 11   Energimærke: D       1938    Ejerudgift: 2.462 kr. / md.
# 12   Energimærke: B       2007    Ejerudgift: 2.717 kr. / md.
# 13   Energimærke: D       1966    Ejerudgift: 3.027 kr. / md.
# 14   Energimærke: C       1974    Ejerudgift: 1.744 kr. / md.
# 15   Energimærke: D       1937    Ejerudgift: 3.558 kr. / md.
# 16   Energimærke: C       1975    Ejerudgift: 2.793 kr. / md.
# 17   Energimærke: C       1975    Ejerudgift: 3.754 kr. / md.
# 18   Energimærke: E       1971    Ejerudgift: 2.548 kr. / md.
# 19   Energimærke: D       1907    Ejerudgift: 4.071 kr. / md.
# 20   Energimærke: E       1935    Ejerudgift: 2.463 kr. / md.
# 21   Energimærke: C       1937    Ejerudgift: 2.099 kr. / md.
# 22   Energimærke: D       1937    Ejerudgift: 3.213 kr. / md.
# 23   Energimærke: D       1938    Ejerudgift: 2.884 kr. / md.
# 24   Energimærke: D       1938    Ejerudgift: 4.315 kr. / md.
# 25   Energimærke: E       1946    Ejerudgift: 2.331 kr. / md.
# 26   Energimærke: D       1934    Ejerudgift: 2.796 kr. / md.
# 27   Energimærke: D       1939    Ejerudgift: 2.897 kr. / md.
# 28   Energimærke: D       1933    Ejerudgift: 4.348 kr. / md.
# 29   Energimærke: D       1908    Ejerudgift: 2.441 kr. / md.
# 30   Energimærke: D       1966    Ejerudgift: 3.017 kr. / md.
# 31   Energimærke: D       1957    Ejerudgift: 3.056 kr. / md.
# 32   Energimærke: D       1957    Ejerudgift: 2.495 kr. / md.
# 33   Energimærke: C       1938    Ejerudgift: 2.657 kr. / md.
# 34   Energimærke: D       1932    Ejerudgift: 4.208 kr. / md.
# 35   Energimærke: D       1935    Ejerudgift: 2.476 kr. / md.
# 36   Energimærke: D       1934    Ejerudgift: 2.250 kr. / md.
# 37   Energimærke: D       1937    Ejerudgift: 3.831 kr. / md.
# 38   Energimærke: E       1934    Ejerudgift: 2.025 kr. / md.
# 39   Energimærke: E       1946    Ejerudgift: 2.463 kr. / md.
# 40   Energimærke: D       1936    Ejerudgift: 2.278 kr. / md.
# 41   Energimærke: D       1899    Ejerudgift: 2.854 kr. / md.
# 42   Energimærke: E       1971    Ejerudgift: 2.338 kr. / md.
# 43   Energimærke: D       1939    Ejerudgift: 3.184 kr. / md.
# 44   Energimærke: D       1938    Ejerudgift: 4.315 kr. / md.
# 45   Energimærke: C       1963    Ejerudgift: 3.138 kr. / md.
# 46   Energimærke: D       1940    Ejerudgift: 2.373 kr. / md.
# 47   Energimærke: C       1937    Ejerudgift: 2.627 kr. / md.
# 48   Energimærke: D       1935    Ejerudgift: 2.986 kr. / md.
#
#                         date
# 0     Oprettet 9. jul. 2021
# 1     Oprettet 9. jul. 2021
# 2     Oprettet 9. jul. 2021
# 3     Oprettet 8. jul. 2021
# 4     Oprettet 8. jul. 2021
# 5     Oprettet 7. jul. 2021
# 6     Oprettet 7. jul. 2021
# 7     Oprettet 7. jul. 2021
# 8     Oprettet 7. jul. 2021
# 9     Oprettet 7. jul. 2021
# 10    Oprettet 5. jul. 2021
# 11   Oprettet 30. jun. 2021
# 12   Oprettet 30. jun. 2021
# 13   Oprettet 30. jun. 2021
# 14   Oprettet 24. jun. 2021
# 15   Oprettet 24. jun. 2021
# 16   Oprettet 24. jun. 2021
# 17   Oprettet 23. jun. 2021
# 18   Oprettet 19. jun. 2021
# 19   Oprettet 19. jun. 2021
# 20   Oprettet 18. jun. 2021
# 21   Oprettet 17. jun. 2021
# 22   Oprettet 17. jun. 2021
# 23   Oprettet 15. jun. 2021
# 24   Oprettet 16. jun. 2021
# 25   Oprettet 15. jun. 2021
# 26   Oprettet 12. jun. 2021
# 27   Oprettet 12. jun. 2021
# 28    Oprettet 9. jun. 2021
# 29    Oprettet 4. jun. 2021
# 30    Oprettet 4. jun. 2021
# 31    Oprettet 2. jun. 2021
# 32    Oprettet 3. jun. 2021
# 33    Oprettet 3. jun. 2021
# 34    Oprettet 3. jun. 2021
# 35    Oprettet 28. maj 2021
# 36    Oprettet 27. maj 2021
# 37    Oprettet 27. maj 2021
# 38    Oprettet 26. maj 2021
# 39    Oprettet 22. maj 2021
# 40    Oprettet 22. maj 2021
# 41    Oprettet 22. maj 2021
# 42    Oprettet 21. maj 2021
# 43    Oprettet 19. maj 2021
# 44    Oprettet 20. maj 2021
# 45    Oprettet 19. maj 2021
# 46    Oprettet 13. maj 2021
# 47    Oprettet 12. maj 2021
# 48    Oprettet 11. maj 2021

# %% [markdown]
# # Cleaning data
#
# - remove comma at the end of address values
# - extract only relevant numbers from combined values
# - remove spaces at start and end of strings
# - transform date into format that can be converted to DateTime datatype
# - put floor and side to lowercase in address
# - fix data types

# %%
df_clean = df.copy()

# %%
# remove comma and space at the end of address values
df_clean.address = df_clean.address.str.rstrip(", ")

# %%
# extract numbers from strings for relevant columns
df_clean.price = df_clean.price.str.strip().str.rstrip(" kr.").str.replace(".","")
# Out:
# <ipython-input-50-cbf5a643e2b0>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean.price = df_clean.price.str.strip().str.rstrip(" kr.").str.replace(".","")

# %%
df_clean.price_m2 = df_clean.price_m2.str.strip().str.rstrip(" kr. / m²").str.replace(".","")
# Out:
# <ipython-input-52-c980f41c8fb6>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean.price_m2 = df_clean.price_m2.str.strip().str.rstrip(" kr. / m²").str.replace(".","")

# %%
df_clean.area = df_clean.area.str.strip().str.rstrip(" m²")

# %%
df_clean.monthly_cost = df_clean.monthly_cost.str.strip().str.rstrip(" kr. / md.").str.lstrip("Ejerudgift: ")\
                                                                                    .str.replace(".","")
# Out:
# <ipython-input-57-3f5de58f18cd>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean.monthly_cost = df_clean.monthly_cost.str.strip().str.rstrip(" kr. / md.").str.lstrip("Ejerudgift: ")\

# %%
df_clean.head()
# Out:
#                     address          city   housing_type    price price_m2  \
# 0       Grønnehøj 9, 2. th.  2720 Vanløse  Ejerlejlighed  2195000    34841
# 1     Arnestedet 21, ST. TH  2720 Vanløse  Ejerlejlighed  2750000    47413
# 2    Markskellet 11, 2. tv.  2720 Vanløse  Ejerlejlighed  3095000    40194
# 3  Ålekistevej 110B, 1. th.  2720 Vanløse  Ejerlejlighed  2450000    45370
# 4       Flakholmen 10, 1 th  2720 Vanløse  Ejerlejlighed  2595000    40546
#
#   area          rooms  ground            energy year_built monthly_cost  \
# 0   63   Værelser: 2    0 m²    Energimærke: D       1936          3163
# 1   58   Værelser: 2    0 m²    Energimærke: D       1935          2608
# 2   77   Værelser: 2    0 m²    Energimærke: C       1936          3628
# 3   54   Værelser: 2    0 m²    Energimærke: D       1937          2240
# 4   64   Værelser: 3    0 m²    Energimærke: D       1938          3094
#
#                       date
# 0   Oprettet 9. jul. 2021
# 1   Oprettet 9. jul. 2021
# 2   Oprettet 9. jul. 2021
# 3   Oprettet 8. jul. 2021
# 4   Oprettet 8. jul. 2021
